# %% [markdown]
# <a href="https://colab.research.google.com/github/Jason-R27/BTE-320/blob/main/BTE_320_In_Class_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sales = float(input("Enter sales ($): "))
cogs = sales * 0.4
gp = sales - cogs

print("Sales: $", sales)
print("Cost of Goods Sold: $", cogs)
print("Gross Profit: $", gp)
# Out:
# Enter sales ($): 12000
# Sales: $ 12000.0
# Cost of Goods Sold: $ 4800.0
# Gross Profit: $ 7200.0

# %%
sales = float(input("Enter sales ($): "))
cogs = sales * 0.4
gp = sales - cogs
tr = float(input("Enter tax rate (%): "))
tax = tr * gp
net = gp - tax

print("Sales: $", sales)
print("Cost of Goods Sold: $", cogs)
print("Gross Profit: $", gp)
print ("Taxes: $", tax)
print("Net income: $:", net)
# Out:
# Enter sales ($): 12000
# Enter tax rate (%): 0.3
# Sales: $ 12000.0
# Cost of Goods Sold: $ 4800.0
# Gross Profit: $ 7200.0
# Taxes: $ 2160.0
# Net income: $: 5040.0
