# %% [markdown]
# <a href="https://colab.research.google.com/github/Jason-R27/BTE-320/blob/main/BTE_320_In_Class_Assignments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 2

# %%
5 + 3.0
# Out:
# 8.0

# %%
1 - 2
# Out:
# -1

# %%
2*3
# Out:
# 6

# %%
6/4
# Out:
# 1.5

# %%
6.0//4
# Out:
# 1.0

# %%
2**3
# Out:
# 8

# %%
2%3
# Out:
# 2

# %%
3.14*3**2
# Out:
# 28.26

# %%
x=5

2<3
2>3
5<=6
9>=3
x==y
x!=y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4068200518.py in <cell line: 0>()
#       5 5<=6
#       6 9>=3
# ----> 7 x==y
#
# NameError: name 'y' is not defined
